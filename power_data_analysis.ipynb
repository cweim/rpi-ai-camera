# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("logs/power_log.csv")

data['timestamp'] = pd.to_datetime(data['timestamp'])
data['temperature'] = pd.to_numeric(data['temperature'])
data['core_voltage'] = pd.to_numeric(data['core_voltage'])
data['cpu_frequency'] = pd.to_numeric(data['cpu_frequency'])

# %%
print(data)
# Out:
#               timestamp  temperature  core_voltage  cpu_frequency
# 0   2025-04-03 16:17:03         55.3        1.2625       1000.104
# 1   2025-04-03 16:17:08         54.8        1.2625       1000.000
# 2   2025-04-03 16:17:13         55.3        1.2625       1000.000
# 3   2025-04-03 16:17:18         55.3        1.2625       1000.000
# 4   2025-04-03 16:17:23         55.8        1.2625       1000.000
# ..                  ...          ...           ...            ...
# 262 2025-04-03 16:39:05         53.2        1.2625       1000.000
# 263 2025-04-03 16:39:10         53.7        1.2625       1000.000
# 264 2025-04-03 16:39:15         54.8        1.2625       1000.000
# 265 2025-04-03 16:39:20         53.7        1.2625       1000.000
# 266 2025-04-03 16:39:25         54.2        1.2625       1000.000
#
# [267 rows x 4 columns]

# %%
fig, (ax1, ax2) = plt.subplots(nrows=2, figsize=(12, 10), sharex=True)

ax1.set_ylabel('Temperature (°C)', color='red')
ax1.plot(data['timestamp'], data['temperature'], color='red')
ax1.tick_params(axis='y', labelcolor='red')
ax1.set_title("Temperature Over Time")

ax2.set_xlabel('Time')
ax2.set_ylabel('Core Voltage (V)', color='blue')
ax2.plot(data['timestamp'], data['core_voltage'], color='blue')
ax2.tick_params(axis='y', labelcolor='blue')
ax2.set_title("Core Voltage Over Time")

fig.tight_layout()

plt.show()
